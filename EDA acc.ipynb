# %% [markdown]
# ## **Imports**

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from google.colab import drive
import os

# %%
df = pd.read_excel("/content/Road Accidents.xlsx")

# %%
df.head()
# Out:
#    Reference Number   Easting  Northing  Number of Vehicles Accident Date  \
# 0       110016014.0  443330.0  439205.0                 2.0    2011-01-12
# 1       110016024.0  425059.0  433371.0                 2.0    2011-01-12
# 2       110016533.0  420683.0  434373.0                 1.0    2011-01-12
# 3       110017112.0  431097.0  433000.0                 1.0    2011-01-12
# 4       110020375.0  429523.0  433820.0                 2.0    2011-01-12
#
#    Time (24hr) 1st Road Class Road Surface  \
# 0        712.0           A(M)   Wet / Damp
# 1        830.0   Unclassified   Wet / Damp
# 2       1215.0              A   Wet / Damp
# 3       1735.0              A          Dry
# 4       1230.0              A          Dry
#
#                        Lighting Conditions          Weather Conditions  \
# 0        Darkness: street lighting unknown  Raining without high winds
# 1          Daylight: street lights present  Raining without high winds
# ...

# %%
df.shape
# Out:
# (2604, 15)

# %% [markdown]
# ## **EDA**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2604 entries, 0 to 2603
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Reference Number     2604 non-null   float64
#  1   Easting              2604 non-null   float64
#  2   Northing             2604 non-null   float64
#  3   Number of Vehicles   2604 non-null   float64
#  4   Accident Date        2604 non-null   datetime64[ns]
#  5   Time (24hr)          2604 non-null   float64
#  6   1st Road Class       2604 non-null   object
#  7   Road Surface         2604 non-null   object
#  8   Lighting Conditions  2604 non-null   object
#  9   Weather Conditions   2604 non-null   object
#  10  Casualty Class       2604 non-null   object
#  11  Casualty Severity    2604 non-null   object
#  12  Sex of Casualty      2604 non-null   object
#  13  Age of Casualty      2604 non-null   float64
#  14  Type of Vehicle      2604 non-null   object
# ...

# %%
df['Casualty Severity'].unique()
# Out:
# array(['Slight', 'Serious', 'Fatal'], dtype=object)

# %%
df['Casualty Severity'].value_counts()
# Out:
# Slight     2313
# Serious     266
# Fatal        25
# Name: Casualty Severity, dtype: int64

# %%
sns.histplot(df['Casualty Severity'], kde=True, bins=10)

# %%
numerical_columns = [col for col in df.columns if df[col].dtype != 'object']
numerical_columns
# Out:
# ['Reference Number',
#  'Easting',
#  'Northing',
#  'Number of Vehicles',
#  'Accident Date',
#  'Time (24hr)',
#  'Age of Casualty']

# %%
plt.figure(figsize=(25, 25))
for i, col in enumerate(numerical_columns):
    plt.subplot(7, 4, i+1)
    sns.histplot(df[col], kde=True, bins=10)

# %%
corr = df.corr()
f,axes = plt.subplots(1,1,figsize = (20,15))
sns.heatmap(corr, square=True, annot = True, linewidth = .5, center = 2, ax = axes, cmap='Blues')

# %%
plt.figure(figsize=(25, 25))
for i, col in enumerate(numerical_columns):
  if type(df[col]) != object: 
      plt.subplot(5, 3, i+1)
      sns.boxenplot(df[col])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e046e7ba14c3> in <module>
#       1 plot = sns.boxplot(
#       2     color='white',
# ----> 3     y=synergy_df["Synergy_percent"],
#       4     x=synergy_df["Min PPI distance"]
#       5 );
#
# NameError: name 'synergy_df' is not defined
